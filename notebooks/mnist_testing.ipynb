# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist

# %%
(_, _), (test_images, _) = mnist.load_data()

# %%
model = load_model("mnist_model.keras")

# %%
def predict_image(img):
    img = img / 255
    img = img.reshape(28, 28, 1)
    plt.imshow(img, cmap="gray")
    img = np.expand_dims(img, axis=0)
    pred = model.predict(img)
    plt.title(f"Predicted Number : {np.argmax(pred)}")

# %%
predict_image(test_images[0])
# Out:
# 1/1 [==============================] - 0s 137ms/step

# %%
predict_image(test_images[52])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
predict_image(test_images[752])
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
predict_image(test_images[979])
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
predict_image(test_images[7678])
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
predict_image(test_images[8784])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
predict_image(test_images[9999])
# Out:
# 1/1 [==============================] - 0s 40ms/step
